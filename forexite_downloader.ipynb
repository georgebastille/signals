# %% [markdown]
# # Downloading historical forex data from forexite
# The url I got from [here](https://www.quantshare.com/sa-421-6-places-to-download-historical-intraday-forex-quotes-data-for-free). It has 1m resolution data for [lots](./forexite_pairs.txt) of symbols. Eah file contains one days data for all symbols. I need to rework the data, one file per symbol. Store in pandas and serialize. Need to handle time zones somehow...

# %%
import datetime
import zipfile
import urllib.request
from pathlib import Path

# %%
date = datetime.datetime.now()
# e.g. url = "https://www.forexite.com/free_forex_quotes/2011/11/011111.zip"
url = "https://www.forexite.com/free_forex_quotes/{}/{:02d}/{:02d}{:02d}{:02d}.zip"
filename = "./forexite/{:04d}-{:02d}-{:02d}.zip"
new_files = []

for x in range(1, 365):
    data_date = date - datetime.timedelta(days=x)
    year = data_date.year
    year_2 = int(str(year)[-2:])
    month = data_date.month
    day = data_date.day
    download = url.format(year, month, day, month, year_2)
    file = filename.format(year, month, day)
    file_obj = Path(file)
    if not file_obj.exists():
        print(download)
        if not Path('./forexite').is_dir():
            Path('./forexite').mkdir()
        urllib.request.urlretrieve(download, file)
        new_files.append(file_obj)
# Out:
# https://www.forexite.com/free_forex_quotes/2020/01/200120.zip
# https://www.forexite.com/free_forex_quotes/2020/01/190120.zip
# https://www.forexite.com/free_forex_quotes/2020/01/180120.zip
# https://www.forexite.com/free_forex_quotes/2019/10/191019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/181019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/171019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/161019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/151019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/141019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/131019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/121019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/111019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/101019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/091019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/081019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/071019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/061019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/051019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/041019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/031019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/021019.zip
# https://www.forexite.com/free_forex_quotes/2019/10/011019.zip
# https://www.forexite.com/free_forex_quotes/2019/09/300919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/290919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/280919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/270919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/260919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/250919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/240919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/230919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/220919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/210919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/200919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/190919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/180919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/170919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/160919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/150919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/140919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/130919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/120919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/110919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/100919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/090919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/080919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/070919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/060919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/050919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/040919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/030919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/020919.zip
# https://www.forexite.com/free_forex_quotes/2019/09/010919.zip
# https://www.forexite.com/free_forex_quotes/2019/08/310819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/300819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/290819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/280819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/270819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/260819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/250819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/240819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/230819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/220819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/210819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/200819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/190819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/180819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/170819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/160819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/150819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/140819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/130819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/120819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/110819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/100819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/090819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/080819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/070819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/060819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/050819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/040819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/030819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/020819.zip
# https://www.forexite.com/free_forex_quotes/2019/08/010819.zip
# https://www.forexite.com/free_forex_quotes/2019/07/310719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/300719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/290719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/280719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/270719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/260719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/250719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/240719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/230719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/220719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/210719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/200719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/190719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/180719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/170719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/160719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/150719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/140719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/130719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/120719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/110719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/100719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/090719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/080719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/070719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/060719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/050719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/040719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/030719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/020719.zip
# https://www.forexite.com/free_forex_quotes/2019/07/010719.zip
# https://www.forexite.com/free_forex_quotes/2019/06/300619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/290619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/280619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/270619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/260619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/250619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/240619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/230619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/220619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/210619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/200619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/190619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/180619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/170619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/160619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/150619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/140619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/130619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/120619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/110619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/100619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/090619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/080619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/070619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/060619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/050619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/040619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/030619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/020619.zip
# https://www.forexite.com/free_forex_quotes/2019/06/010619.zip
# https://www.forexite.com/free_forex_quotes/2019/05/310519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/300519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/290519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/280519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/270519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/260519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/250519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/240519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/230519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/220519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/210519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/200519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/190519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/180519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/170519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/160519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/150519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/140519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/130519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/120519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/110519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/100519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/090519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/080519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/070519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/060519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/050519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/040519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/030519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/020519.zip
# https://www.forexite.com/free_forex_quotes/2019/05/010519.zip
# https://www.forexite.com/free_forex_quotes/2019/04/300419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/290419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/280419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/270419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/260419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/250419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/240419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/230419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/220419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/210419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/200419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/190419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/180419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/170419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/160419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/150419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/140419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/130419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/120419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/110419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/100419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/090419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/080419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/070419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/060419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/050419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/040419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/030419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/020419.zip
# https://www.forexite.com/free_forex_quotes/2019/04/010419.zip
# https://www.forexite.com/free_forex_quotes/2019/03/310319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/300319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/290319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/280319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/270319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/260319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/250319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/240319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/230319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/220319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/210319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/200319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/190319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/180319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/170319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/160319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/150319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/140319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/130319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/120319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/110319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/100319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/090319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/080319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/070319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/060319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/050319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/040319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/030319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/020319.zip
# https://www.forexite.com/free_forex_quotes/2019/03/010319.zip
# https://www.forexite.com/free_forex_quotes/2019/02/280219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/270219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/260219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/250219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/240219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/230219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/220219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/210219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/200219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/190219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/180219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/170219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/160219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/150219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/140219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/130219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/120219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/110219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/100219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/090219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/080219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/070219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/060219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/050219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/040219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/030219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/020219.zip
# https://www.forexite.com/free_forex_quotes/2019/02/010219.zip
# https://www.forexite.com/free_forex_quotes/2019/01/310119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/300119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/290119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/280119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/270119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/260119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/250119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/240119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/230119.zip
# https://www.forexite.com/free_forex_quotes/2019/01/220119.zip

# %% [markdown]
# ### Converting to csv files, one ticker per file
# I want one file for each currency pair. I would like it to read the current file, figure out if there is any new data and add it, and then save the file again. I will read and analyse the files in a different codepath.
#
# In fact, lets convert the forexite data into csv files first, these are human readable and pandas readable.
# Thoughts:
# - Do I dump everything into the csv, then sort and dedupe
# - Should I use a list of tuples, (datetime, o, h, l, c)
# - I could load the existing file (if it exists) into a set, each new file can check to see if it is duplicated
# - I only need to use the date to dedupe, so, from each file, get the date, check the set. If not there, we add all the rows to the list of tuples
# - Then we sort them and write them out
# - This might have quite high memory requirements, can we make some assumptions about the order the files are presented to us? Would be challenging if there were gaps in the data, is this an edge case?
# - Lets start with the first run case, we can optimise later if need be.

# %%
# function that takes a filename
# function that takes a row and a list
def parse_row(row_from_file):
    # Row looks like:
    # EURUSD,20191101,000900,1.1150,1.1150,1.1150,1.1150
    tokens = row_from_file.split(',')
    assert len(tokens) == 7, f"Not enough tokens in: {row_from_file}"
    
    date_time_str = str(tokens[1]) + str(tokens[2])
    dt = datetime.datetime.strptime(date_time_str, '%Y%m%d%H%M%S')
    
    ticker = tokens[0].strip()
    opener = tokens[3].strip()
    high = tokens[4].strip()
    low = tokens[5].strip()
    close = tokens[6].strip()
    
    return ticker, (dt, opener, high, low, close)

# %%
file_handles = {}

print("Generating file list")
new_files = None # HACK!
files = new_files
if not new_files:
    files = Path('./forexite/').glob('*.zip')
files = sorted(list(files))


if not Path('./csv').is_dir():
    print("Creating output directory")
    Path('./csv').mkdir()
    
print("Parsing available tickers and Opening output files")
with zipfile.ZipFile(files[-1]) as z:
    fn = z.namelist()[0]
    print(f"Processing {fn}")
    with z.open(fn) as f:
        next(f)
        for row in f:
            clean_row = row.decode("utf-8").strip()
            ticker, ohlc = parse_row(clean_row)
            if ticker not in file_handles:
                file_handles[ticker] = open(f"./csv/{ticker}.csv", "a")

print("Parsing files")
for file in files:
    with zipfile.ZipFile(file) as z:
        fn = z.namelist()[0]
        print(f"Processing {fn}")
        with z.open(fn) as f:
            next(f)
            for row in f:
                clean_row = row.decode("utf-8").strip()
                ticker, ohlc = parse_row(clean_row)
                if ticker not in file_handles:
                    continue
                file_handles[ticker].write("{}, {}, {}, {}, {}\n".format(*ohlc))
                
print("Closing output files")
for _, handle in file_handles.items():
    handle.close()
# Out:
# Generating file list
# Parsing available tickers and Opening output files
# Processing 200120.txt
# Parsing files
# Processing 220119.txt
# Processing 230119.txt
# Processing 240119.txt
# Processing 250119.txt
# Processing 260119.txt
# Processing 270119.txt
# Processing 280119.txt
# Processing 290119.txt
# Processing 300119.txt
# Processing 310119.txt
# Processing 010219.txt
# Processing 020219.txt
# Processing 030219.txt
# Processing 040219.txt
# Processing 050219.txt
# Processing 060219.txt
# Processing 070219.txt
# Processing 080219.txt
# Processing 090219.txt
# Processing 100219.txt
# Processing 110219.txt
# Processing 120219.txt
# Processing 130219.txt
# Processing 140219.txt
# Processing 150219.txt
# Processing 160219.txt
# Processing 170219.txt
# Processing 180219.txt
# Processing 190219.txt
# Processing 200219.txt
# Processing 210219.txt
# Processing 220219.txt
# Processing 230219.txt
# Processing 240219.txt
# Processing 250219.txt
# Processing 260219.txt
# Processing 270219.txt
# Processing 280219.txt
# Processing 010319.txt
# Processing 020319.txt
# Processing 030319.txt
# Processing 040319.txt
# Processing 050319.txt
# Processing 060319.txt
# Processing 070319.txt
# Processing 080319.txt
# Processing 090319.txt
# Processing 100319.txt
# Processing 110319.txt
# Processing 120319.txt
# Processing 130319.txt
# Processing 140319.txt
# Processing 150319.txt
# Processing 160319.txt
# Processing 170319.txt
# Processing 180319.txt
# Processing 190319.txt
# Processing 200319.txt
# Processing 210319.txt
# Processing 220319.txt
# Processing 230319.txt
# Processing 240319.txt
# Processing 250319.txt
# Processing 260319.txt
# Processing 270319.txt
# Processing 280319.txt
# Processing 290319.txt
# Processing 300319.txt
# Processing 310319.txt
# Processing 010419.txt
# Processing 020419.txt
# Processing 030419.txt
# Processing 040419.txt
# Processing 050419.txt
# Processing 060419.txt
# Processing 070419.txt
# Processing 080419.txt
# Processing 090419.txt
# Processing 100419.txt
# Processing 110419.txt
# Processing 120419.txt
# Processing 130419.txt
# Processing 140419.txt
# Processing 150419.txt
# Processing 160419.txt
# Processing 170419.txt
# Processing 180419.txt
# Processing 190419.txt
# Processing 200419.txt
# Processing 210419.txt
# Processing 220419.txt
# Processing 230419.txt
# Processing 240419.txt
# Processing 250419.txt
# Processing 260419.txt
# Processing 270419.txt
# Processing 280419.txt
# Processing 290419.txt
# Processing 300419.txt
# Processing 010519.txt
# Processing 020519.txt
# Processing 030519.txt
# Processing 040519.txt
# Processing 050519.txt
# Processing 060519.txt
# Processing 070519.txt
# Processing 080519.txt
# Processing 090519.txt
# Processing 100519.txt
# Processing 110519.txt
# Processing 120519.txt
# Processing 130519.txt
# Processing 140519.txt
# Processing 150519.txt
# Processing 160519.txt
# Processing 170519.txt
# Processing 180519.txt
# Processing 190519.txt
# Processing 200519.txt
# Processing 210519.txt
# Processing 220519.txt
# Processing 230519.txt
# Processing 240519.txt
# Processing 250519.txt
# Processing 260519.txt
# Processing 270519.txt
# Processing 280519.txt
# Processing 290519.txt
# Processing 300519.txt
# Processing 310519.txt
# Processing 010619.txt
# Processing 020619.txt
# Processing 030619.txt
# Processing 040619.txt
# Processing 050619.txt
# Processing 060619.txt
# Processing 070619.txt
# Processing 080619.txt
# Processing 090619.txt
# Processing 100619.txt
# Processing 110619.txt
# Processing 120619.txt
# Processing 130619.txt
# Processing 140619.txt
# Processing 150619.txt
# Processing 160619.txt
# Processing 170619.txt
# Processing 180619.txt
# Processing 190619.txt
# Processing 200619.txt
# Processing 210619.txt
# Processing 220619.txt
# Processing 230619.txt
# Processing 240619.txt
# Processing 250619.txt
# Processing 260619.txt
# Processing 270619.txt
# Processing 280619.txt
# Processing 290619.txt
# Processing 300619.txt
# Processing 010719.txt
# Processing 020719.txt
# Processing 030719.txt
# Processing 040719.txt
# Processing 050719.txt
# Processing 060719.txt
# Processing 070719.txt
# Processing 080719.txt
# Processing 090719.txt
# Processing 100719.txt
# Processing 110719.txt
# Processing 120719.txt
# Processing 130719.txt
# Processing 140719.txt
# Processing 150719.txt
# Processing 160719.txt
# Processing 170719.txt
# Processing 180719.txt
# Processing 190719.txt
# Processing 200719.txt
# Processing 210719.txt
# Processing 220719.txt
# Processing 230719.txt
# Processing 240719.txt
# Processing 250719.txt
# Processing 260719.txt
# Processing 270719.txt
# Processing 280719.txt
# Processing 290719.txt
# Processing 300719.txt
# Processing 310719.txt
# Processing 010819.txt
# Processing 020819.txt
# Processing 030819.txt
# Processing 040819.txt
# Processing 050819.txt
# Processing 060819.txt
# Processing 070819.txt
# Processing 080819.txt
# Processing 090819.txt
# Processing 100819.txt
# Processing 110819.txt
# Processing 120819.txt
# Processing 130819.txt
# Processing 140819.txt
# Processing 150819.txt
# Processing 160819.txt
# Processing 170819.txt
# Processing 180819.txt
# Processing 190819.txt
# Processing 200819.txt
# Processing 210819.txt
# Processing 220819.txt
# Processing 230819.txt
# Processing 240819.txt
# Processing 250819.txt
# Processing 260819.txt
# Processing 270819.txt
# Processing 280819.txt
# Processing 290819.txt
# Processing 300819.txt
# Processing 310819.txt
# Processing 010919.txt
# Processing 020919.txt
# Processing 030919.txt
# Processing 040919.txt
# Processing 050919.txt
# Processing 060919.txt
# Processing 070919.txt
# Processing 080919.txt
# Processing 090919.txt
# Processing 100919.txt
# Processing 110919.txt
# Processing 120919.txt
# Processing 130919.txt
# Processing 140919.txt
# Processing 150919.txt
# Processing 160919.txt
# Processing 170919.txt
# Processing 180919.txt
# Processing 190919.txt
# Processing 200919.txt
# Processing 210919.txt
# Processing 220919.txt
# Processing 230919.txt
# Processing 240919.txt
# Processing 250919.txt
# Processing 260919.txt
# Processing 270919.txt
# Processing 280919.txt
# Processing 290919.txt
# Processing 300919.txt
# Processing 011019.txt
# Processing 021019.txt
# Processing 031019.txt
# Processing 041019.txt
# Processing 051019.txt
# Processing 061019.txt
# Processing 071019.txt
# Processing 081019.txt
# Processing 091019.txt
# Processing 101019.txt
# Processing 111019.txt
# Processing 121019.txt
# Processing 131019.txt
# Processing 141019.txt
# Processing 151019.txt
# Processing 161019.txt
# Processing 171019.txt
# Processing 181019.txt
# Processing 191019.txt
# Processing 201019.txt
# Processing 211019.txt
# Processing 221019.txt
# Processing 231019.txt
# Processing 241019.txt
# Processing 251019.txt
# Processing 261019.txt
# Processing 271019.txt
# Processing 281019.txt
# Processing 291019.txt
# Processing 301019.txt
# Processing 311019.txt
# Processing 011119.txt
# Processing 021119.txt
# Processing 031119.txt
# Processing 041119.txt
# Processing 051119.txt
# Processing 061119.txt
# Processing 071119.txt
# Processing 081119.txt
# Processing 091119.txt
# Processing 101119.txt
# Processing 111119.txt
# Processing 121119.txt
# Processing 131119.txt
# Processing 141119.txt
# Processing 151119.txt
# Processing 161119.txt
# Processing 171119.txt
# Processing 181119.txt
# Processing 191119.txt
# Processing 201119.txt
# Processing 211119.txt
# Processing 221119.txt
# Processing 231119.txt
# Processing 241119.txt
# Processing 251119.txt
# Processing 261119.txt
# Processing 271119.txt
# Processing 281119.txt
# Processing 291119.txt
# Processing 301119.txt
# Processing 011219.txt
# Processing 021219.txt
# Processing 031219.txt
# Processing 041219.txt
# Processing 051219.txt
